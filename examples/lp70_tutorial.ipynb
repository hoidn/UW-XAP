# %%
rm -r cache/*

# %%
# %matplotlib notebook
from dataccess.nbfunctions import *
from dataccess import lp70
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plot individual events:

# %%
[p1, p2]= lp70.plot_run_events('cspad1', [72], [range(1,3)], plot_mean = False,
                     plot_individual = True)
# Out:
# <div id="9a091ac2-7873-4f16-a942-deaf4ecad10c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9a091ac2-7873-4f16-a942-deaf4ecad10c", [{"showlegend": true, "name": "run 72, event 1", "mode": "lines", "y": [14827.23635286494, 14109.181538267698, 12816.593988067423, 11237.209491768423, 10266.617384895166, 10239.520166366752, 10821.888875061439, 11626.271387714181, 11738.265035994187, 11540.770084479784, 11389.146248616551, 11003.955102492751, 10711.756066704947, 10507.45613557688, 10479.345511466854, 10191.63264110314, 9648.043386210473, 9128.88495485442, 8713.293801394278, 8533.45075100596, 8404.907337502515, 8250.047960321477, 8156.733690407916, 8040.344129937668, 7971.327411131207, 7866.824535564063, 7814.157107278427, 7790.930484230326, 7776.883850897671, 7810.863430338864, 7811.4609474709105, 77
# ...

# %% [markdown]
# ### Plot mean:

# %%
[p1mean]= lp70.plot_run_events('cspad1', [72], [range(1,3)],
                               plot_mean = True, plot_individual = False)
# Out:
# <div id="01982204-914f-4f5d-ba87-bf4b3d1f6c80" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("01982204-914f-4f5d-ba87-bf4b3d1f6c80", [{"showlegend": true, "name": "runs [72]: mean", "mode": "lines", "y": [11764.7854766555, 11299.189934993707, 10413.654390372281, 9386.664980117055, 8852.99096858723, 8752.63604140627, 9092.014170070626, 9693.411982149117, 9924.65735808338, 10131.525354359728, 10685.515690258817, 11005.482354644817, 10989.792419227259, 10892.352385684382, 10877.188284560696, 10738.68947203016, 10462.047706225283, 10106.407429499133, 9528.816218560582, 8900.657031658986, 8362.121793947648, 7868.693740756517, 7433.858215019816, 7149.81273622196, 6988.249860867989, 6811.7027947430615, 6725.370779026212, 6676.907850984023, 6601.7919570869435, 6566.909062994344, 6518.7952353937835, 6481.9
# ...

# %% [markdown]
# ### Plot several patterns at once:

# %%
[p2mean]= lp70.plot_run_events('cspad0', [72], [range(1,3)],
                               plot_mean = True, plot_individual = False,
                              show = False)

# %%
lp70.plot_patterns([p1mean, p2mean], labels = ['cspad1', 'cspad2'])
# Out:
# <div id="495270fb-8fdf-4799-9762-75566f7c4765" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("495270fb-8fdf-4799-9762-75566f7c4765", [{"showlegend": true, "name": "cspad1", "mode": "lines", "y": [11764.7854766555, 11299.189934993707, 10413.654390372281, 9386.664980117055, 8852.99096858723, 8752.63604140627, 9092.014170070626, 9693.411982149117, 9924.65735808338, 10131.525354359728, 10685.515690258817, 11005.482354644817, 10989.792419227259, 10892.352385684382, 10877.188284560696, 10738.68947203016, 10462.047706225283, 10106.407429499133, 9528.816218560582, 8900.657031658986, 8362.121793947648, 7868.693740756517, 7433.858215019816, 7149.81273622196, 6988.249860867989, 6811.7027947430615, 6725.370779026212, 6676.907850984023, 6601.7919570869435, 6566.909062994344, 6518.7952353937835, 6481.9732330697
# ...

# %% [markdown]
# ### See the raw CSPAD data:

# %%
utils.show_image(p1mean.image, rmin = 2000, rmax = 4500)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Get the powder pattern data:

# %%
p1.angles, p1.intensities
# Out:
# (array([  32.15287686,   32.2244226 ,   32.29596833, ...,  103.55551929,
#          103.62706502,  103.69861076]),
#  array([ 15014.95996094,  14234.49023438,  12957.48372396, ...,
#           7123.48977811,   4838.46150716,   4161.64990234]))
